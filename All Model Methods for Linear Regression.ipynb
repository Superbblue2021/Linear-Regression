# %%
import itertools
import time
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.metrics import mean_squared_error

# %matplotlib inline
plt.style.use('ggplot')

# %%
dataset = pd.read_csv("C:/Users/pc/Desktop/Mini 2/Linear Modelling/fulltrain.csv")

# %%
def press_statistic(y_true, y_pred, xs):
    res = y_pred - y_true
    hat = xs.dot(np.linalg.pinv(xs))
    den = (1 - np.diagonal(hat))
    sqr = np.square(res/den)
    return sqr.sum()

# %%
def fit_linear_reg(X,Y):
    #Fit linear regression model and return RSS and R squared values
    model_k = linear_model.LinearRegression(fit_intercept = True)
    model_k.fit(X,Y)
    RSS = mean_squared_error(Y,model_k.predict(X)) * len(Y)
    R_squared = model_k.score(X,Y)
    PRESS = press_statistic(Y,model_k.predict(X),X)
    return RSS, R_squared, PRESS

# %%
# # to calculate MSE for whole variables
# Y_whole = dataset["life_expectancy"]
# X_whole = dataset.drop(columns = "life_expectancy", axis = 1)
# tmp_result_whole = fit_linear_reg(X_whole,Y_whole)
# MSE = tmp_result_whole[0]/len(Y_whole)

# %%
#Importing tqdm for the progress bar
from tqdm import trange, tqdm_notebook

#Initialization variables
Y = dataset["life_expectancy"]
X = dataset.drop(columns = "life_expectancy", axis = 1)
k = 19 #number of total original margin
RSS_list, R_squared_list, PRESS_list, feature_list = [],[],[],[]
numb_features = []

#Looping over k = 12 to k = 15 features in X
for k in trange(10,13, desc = 'Loop...'):
    #Looping over all possible combinations: from 19 choose k
    for combo in itertools.combinations(X.columns,k):
        tmp_result = fit_linear_reg(X[list(combo)],Y)   #Store temp result 
        RSS_list.append(tmp_result[0])                  #Append lists
        R_squared_list.append(tmp_result[1])
        PRESS_list.append(tmp_result[2])
        feature_list.append(combo)
        numb_features.append(len(combo))   

#Store in DataFrame
df = pd.DataFrame({'numb_features': numb_features,'RSS': RSS_list, 'R_squared':R_squared_list,'features':feature_list,'PRESS':PRESS_list})
df.head(3)
# Out:
# Loop...: 100%|██████████| 3/3 [46:11<00:00, 968.28s/it]
#    numb_features           RSS  R_squared  \
# 0             10  27892.048475   0.682734
# 1             10  28270.256327   0.678432
# 2             10  27588.738814   0.686184
#
#                                             features         PRESS
# 0  (status, adult_mortality, infant_deaths, alcoh...  28413.043728
# 1  (status, adult_mortality, infant_deaths, alcoh...  28810.969741
# 2  (status, adult_mortality, infant_deaths, alcoh...  28114.820497

# %%
# to calculate MSE for whole variables
Y_whole = dataset["life_expectancy"]
X_whole = dataset.drop(columns = "life_expectancy", axis = 1)
tmp_result_whole = fit_linear_reg(X_whole,Y_whole)
MSE = tmp_result_whole[0]/len(Y_whole)

# %%
#Initializing useful variables
m = len(Y)
#p = 19
#hat_sigma_squared = (1/(m - p -1)) * min(df['RSS'])

#Computing
df['C_p'] = df['RSS']/MSE - m+2*(df['numb_features']) # formular from Wiki
df['AIC'] = m*np.log(df['RSS']/m)+2*df['numb_features']
df['R_squared_adj'] = 1 - ( (1 - df['R_squared'])*(m-1)/(m-df['numb_features'] -1))
df
# Out:
#         numb_features           RSS  R_squared  \
# 0                  10  27892.048475   0.682734
# 1                  10  28270.256327   0.678432
# 2                  10  27588.738814   0.686184
# 3                  10  21970.801532   0.750087
# 4                  10  28164.706694   0.679632
# 5                  10  28269.530269   0.678440
# 6                  10  27647.301627   0.685518
# 7                  10  27775.175817   0.684063
# 8                  10  23056.707605   0.737735
# 9                  10  22396.915594   0.745240
# 10                 10  29354.756134   0.666096
# 11                 10  28724.621835   0.673264
# 12                 10  22969.728827   0.738724
# 13                 10  29241.093169   0.667389
# 14                 10  29137.271317   0.668570
# 15                 10  28671.505240   0.673868
# 16                 10  28922.795110   0.671009
# 17                 10  23710.418599   0.730299
# 18                 10  23159.228789   0.736569
# 19                 10  28896.227341   0.671312
# 20                 10  23557.990393   0.732033
# 21                 10  29845.316294   0.660516
# 22                 10  29695.866036   0.662216
# 23                 10  29412.286700   0.665441
# 24                 10  29623.705668   0.663037
# 25                 10  24020.531881   0.726772
# 26                 10  23294.611468   0.735029
# 27                 10  22685.462297   0.741958
# 28                 10  28760.693445   0.672853
# 29                 10  28719.819952   0.673318
# ...               ...           ...        ...
# 218318             12  34720.918387   0.605057
# 218319             12  19546.971473   0.777657
# 218320             12  19556.947906   0.777544
# 218321             12  19625.887214   0.776760
# 218322             12  19639.481723   0.776605
# 218323             12  21385.140043   0.756749
# 218324             12  21068.531650   0.760350
# 218325             12  19178.393357   0.781850
# 218326             12  19149.475247   0.782179
# 218327             12  19189.547209   0.781723
# 218328             12  19834.165122   0.774391
# 218329             12  33899.160440   0.614404
# 218330             12  19228.356047   0.781282
# 218331             12  19195.713361   0.781653
# 218332             12  19283.497825   0.780654
# 218333             12  19203.903240   0.781560
# 218334             12  19590.670583   0.777160
# 218335             12  21301.617445   0.757699
# 218336             12  20950.496090   0.761693
# 218337             12  19064.551573   0.783145
# 218338             12  19043.410012   0.783385
# 218339             12  19101.813226   0.782721
# 218340             12  19769.838624   0.775122
# 218341             12  33766.138340   0.615917
# 218342             12  19085.526303   0.782906
# 218343             12  19093.548424   0.782815
# 218344             12  19144.271306   0.782238
# 218345             12  19171.140615   0.781932
# 218346             12  19521.613201   0.777946
# 218347             12  19183.986986   0.781786
#
#                                                  features         PRESS  \
# 0       (status, adult_mortality, infant_deaths, alcoh...  28413.043728
# 1       (status, adult_mortality, infant_deaths, alcoh...  28810.969741
# 2       (status, adult_mortality, infant_deaths, alcoh...  28114.820497
# 3       (status, adult_mortality, infant_deaths, alcoh...  22469.608982
# 4       (status, adult_mortality, infant_deaths, alcoh...  28655.602122
# 5       (status, adult_mortality, infant_deaths, alcoh...  28798.125614
# 6       (status, adult_mortality, infant_deaths, alcoh...  28168.951384
# 7       (status, adult_mortality, infant_deaths, alcoh...  28299.300462
# 8       (status, adult_mortality, infant_deaths, alcoh...  23472.650795
# 9       (status, adult_mortality, infant_deaths, alcoh...  22772.110232
# 10      (status, adult_mortality, infant_deaths, alcoh...  29892.522479
# 11      (status, adult_mortality, infant_deaths, alcoh...  29247.985759
# 12      (status, adult_mortality, infant_deaths, alcoh...  23490.276052
# 13      (status, adult_mortality, infant_deaths, alcoh...  29733.327591
# 14      (status, adult_mortality, infant_deaths, alcoh...  29659.932029
# 15      (status, adult_mortality, infant_deaths, alcoh...  29189.323001
# 16      (status, adult_mortality, infant_deaths, alcoh...  29442.271163
# 17      (status, adult_mortality, infant_deaths, alcoh...  24150.577109
# 18      (status, adult_mortality, infant_deaths, alcoh...  23544.178740
# 19      (status, adult_mortality, infant_deaths, alcoh...  29436.691944
# 20      (status, adult_mortality, infant_deaths, alcoh...  24120.914548
# 21      (status, adult_mortality, infant_deaths, alcoh...  30369.410787
# 22      (status, adult_mortality, infant_deaths, alcoh...  30258.520501
# 23      (status, adult_mortality, infant_deaths, alcoh...  29970.371483
# 24      (status, adult_mortality, infant_deaths, alcoh...  30181.437028
# 25      (status, adult_mortality, infant_deaths, alcoh...  24480.342254
# 26      (status, adult_mortality, infant_deaths, alcoh...  23686.190956
# 27      (status, adult_mortality, infant_deaths, alcoh...  23200.710968
# 28      (status, adult_mortality, infant_deaths, alcoh...  29258.994105
# 29      (status, adult_mortality, infant_deaths, alcoh...  29249.315780
# ...                                                   ...           ...
# 218318  (hepatitis_b, measles, under-five_deaths, poli...  35694.329836
# 218319  (hepatitis_b, measles, under-five_deaths, poli...  20138.607309
# 218320  (hepatitis_b, measles, under-five_deaths, poli...  20143.559257
# 218321  (hepatitis_b, measles, under-five_deaths, tota...  20232.310088
# 218322  (hepatitis_b, measles, polio, total_expenditur...  20166.842608
# 218323  (hepatitis_b, bmi, under-five_deaths, polio, t...  22014.169101
# 218324  (hepatitis_b, bmi, under-five_deaths, polio, t...  21628.267580
# 218325  (hepatitis_b, bmi, under-five_deaths, polio, t...  19714.138774
# 218326  (hepatitis_b, bmi, under-five_deaths, polio, t...  19688.603408
# 218327  (hepatitis_b, bmi, under-five_deaths, polio, t...  19726.327911
# 218328  (hepatitis_b, bmi, under-five_deaths, polio, t...  20408.348559
# 218329  (hepatitis_b, bmi, under-five_deaths, polio, t...  34759.595942
# 218330  (hepatitis_b, bmi, under-five_deaths, polio, t...  19767.362955
# 218331  (hepatitis_b, bmi, under-five_deaths, polio, d...  19726.886034
# 218332  (hepatitis_b, bmi, under-five_deaths, total_ex...  19833.067760
# 218333  (hepatitis_b, bmi, polio, total_expenditure, d...  19704.986931
# 218334  (hepatitis_b, under-five_deaths, polio, total_...  20161.475783
# 218335  (measles, bmi, under-five_deaths, polio, total...  21953.748167
# 218336  (measles, bmi, under-five_deaths, polio, total...  21545.560664
# 218337  (measles, bmi, under-five_deaths, polio, total...  19625.663071
# 218338  (measles, bmi, under-five_deaths, polio, total...  19607.108832
# 218339  (measles, bmi, under-five_deaths, polio, total...  19654.574367
# 218340  (measles, bmi, under-five_deaths, polio, total...  20366.278329
# 218341  (measles, bmi, under-five_deaths, polio, total...  34693.469921
# 218342  (measles, bmi, under-five_deaths, polio, total...  19653.451699
# 218343  (measles, bmi, under-five_deaths, polio, dipht...  19651.997100
# 218344  (measles, bmi, under-five_deaths, total_expend...  19720.409231
# 218345  (measles, bmi, polio, total_expenditure, dipht...  19679.825512
# 218346  (measles, under-five_deaths, polio, total_expe...  20118.837333
# 218347  (bmi, under-five_deaths, polio, total_expendit...  19726.366489
#
#                 C_p          AIC  R_squared_adj
# 0       1056.281650  3695.614031       0.679958
# 1       1085.981215  3711.156786       0.675618
# 2       1032.463622  3682.996228       0.683438
# 3        591.303305  3420.238152       0.747900
# 4       1077.692709  3706.840156       0.676830
# 5       1085.924200  3711.127147       0.675627
# 6       1037.062390  3685.443235       0.682766
# 7       1047.103979  3690.768406       0.681299
# 8        676.576359  3475.909836       0.735440
# 9        624.764806  3442.405204       0.743011
# 10      1171.143839  3754.598358       0.663175
# 11      1121.661220  3729.556646       0.670405
# 12       669.746168  3471.548272       0.736438
# 13      1162.218216  3750.121343       0.664479
# 14      1154.065387  3746.016722       0.665670
# 15      1117.490128  3727.420733       0.671014
# 16      1137.223193  3737.490839       0.668131
# 17       727.910387  3508.173166       0.727939
# 18       684.627050  3481.029699       0.734264
# 19      1135.136903  3736.430316       0.668436
# 20       715.940642  3500.730447       0.729688
# 21      1209.666105  3773.723989       0.657546
# 22      1197.930210  3767.930824       0.659261
# 23      1175.661547  3756.857797       0.662514
# 24      1192.263665  3765.123214       0.660089
# 25       752.262683  3523.168709       0.724381
# 26       695.258259  3487.756035       0.732711
# 27       647.423542  3457.177603       0.739700
# 28      1124.493819  3731.004899       0.669991
# 29      1121.284142  3729.363716       0.670460
# ...             ...          ...            ...
# 218318  1596.532993  3952.340831       0.600903
# 218319   404.966962  3289.342468       0.775319
# 218320   405.750383  3289.931300       0.775204
# 218321   411.163987  3293.992060       0.774412
# 218322   412.231524  3294.791138       0.774256
# 218323   549.313008  3393.059289       0.754190
# 218324   524.450669  3375.846509       0.757830
# 218325   376.023592  3267.374851       0.779556
# 218326   373.752737  3265.633481       0.779888
# 218327   376.899472  3268.045805       0.779427
# 218328   427.519447  3306.174250       0.772018
# 218329  1532.002725  3924.700117       0.610349
# 218330   379.947017  3270.377291       0.778981
# 218331   377.383682  3268.416558       0.779356
# 218332   384.277141  3273.681918       0.778347
# 218333   378.026809  3268.908809       0.779262
# 218334   408.398527  3291.919465       0.774817
# 218335   542.754220  3388.543359       0.755150
# 218336   515.181679  3369.363094       0.759186
# 218337   367.083927  3260.504366       0.780864
# 218338   365.423742  3259.223932       0.781107
# 218339   370.009977  3262.757657       0.780436
# 218340   422.468073  3302.425496       0.772757
# 218341  1521.556886  3920.162851       0.611878
# 218342   368.731012  3261.773293       0.780623
# 218343   369.360966  3262.258246       0.780531
# 218344   373.344087  3265.319835       0.779948
# 218345   375.454056  3266.938358       0.779639
# 218346   402.975651  3287.844413       0.775610
# 218347   376.462844  3267.711382       0.779491
#
# [218348 rows x 8 columns]

# %%
df.to_csv("results.cvs")

# %%
df.sort_values(by="PRESS").head(3)
# Out:
#         numb_features           RSS  R_squared  \
# 170709             12  14806.325615   0.831581
# 170710             12  14806.064061   0.831584
# 170815             12  14812.595592   0.831510
#
#                                                  features         PRESS  \
# 170709  (status, adult_mortality, infant_deaths, alcoh...  15200.825245
# 170710  (status, adult_mortality, infant_deaths, alcoh...  15200.926468
# 170815  (status, adult_mortality, infant_deaths, alcoh...  15206.618220
#
#               C_p          AIC  R_squared_adj
# 170709  32.697796  2968.800658       0.829810
# 170710  32.677257  2968.780273       0.829813
# 170815  33.190159  2969.289235       0.829738

# %%
df.sort_values(by="C_p").head(3)
# Out:
#         numb_features           RSS  R_squared  \
# 170710             12  14806.064061   0.831584
# 170709             12  14806.325615   0.831581
# 170815             12  14812.595592   0.831510
#
#                                                  features         PRESS  \
# 170710  (status, adult_mortality, infant_deaths, alcoh...  15200.926468
# 170709  (status, adult_mortality, infant_deaths, alcoh...  15200.825245
# 170815  (status, adult_mortality, infant_deaths, alcoh...  15206.618220
#
#               C_p          AIC  R_squared_adj
# 170710  32.677257  2968.780273       0.829813
# 170709  32.697796  2968.800658       0.829810
# 170815  33.190159  2969.289235       0.829738

# %%
df.sort_values(by="AIC").head(3)
# Out:
#         numb_features           RSS  R_squared  \
# 170710             12  14806.064061   0.831584
# 170709             12  14806.325615   0.831581
# 170815             12  14812.595592   0.831510
#
#                                                  features         PRESS  \
# 170710  (status, adult_mortality, infant_deaths, alcoh...  15200.926468
# 170709  (status, adult_mortality, infant_deaths, alcoh...  15200.825245
# 170815  (status, adult_mortality, infant_deaths, alcoh...  15206.618220
#
#               C_p          AIC  R_squared_adj
# 170710  32.677257  2968.780273       0.829813
# 170709  32.697796  2968.800658       0.829810
# 170815  33.190159  2969.289235       0.829738

# %%
df.sort_values(by="R_squared_adj",ascending=False).head(3)
# Out:
#         numb_features           RSS  R_squared  \
# 170710             12  14806.064061   0.831584
# 170709             12  14806.325615   0.831581
# 170815             12  14812.595592   0.831510
#
#                                                  features         PRESS  \
# 170710  (status, adult_mortality, infant_deaths, alcoh...  15200.926468
# 170709  (status, adult_mortality, infant_deaths, alcoh...  15200.825245
# 170815  (status, adult_mortality, infant_deaths, alcoh...  15206.618220
#
#               C_p          AIC  R_squared_adj
# 170710  32.677257  2968.780273       0.829813
# 170709  32.697796  2968.800658       0.829810
# 170815  33.190159  2969.289235       0.829738

# %%
df.iloc[170710]["features"]
# Out:
# ('status',
#  'adult_mortality',
#  'infant_deaths',
#  'alcohol',
#  'percentage_expenditure',
#  'bmi',
#  'under-five_deaths',
#  'polio',
#  'hiv/aids',
#  'thinness_5-9_years',
#  'income_composition_of_resources',
#  'schooling')
